# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsyahpn10/Ramenratings/blob/main/Ramen_Ratings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ramen Ratings**
# By : Hafsyah Putri Nabila

# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/hafsyahpn10/Ramenratings/main/ramen-ratings.csv')

# %%
data.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# Hapus Duplikasi Data

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten]
# Index: []

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# Replace United States ke USA dan Holland ke Netherlands

# %%
data.replace(to_replace={'United States':'USA','Holland':'Netherlands'},inplace=False)
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
data[(data['Country']=='United States') & (data['Country']=='Holland') ]
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten]
# Index: []

# %% [markdown]
# Melihat Nilai Null

# %%
data.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
data['Style'].unique()
# Out:
# array(['Cup', 'Pack', 'Tray', 'Bowl', 'Box', 'Can', 'Bar', nan],
#       dtype=object)

# %% [markdown]
# Mengahapus nilai null

# %%
data_baru=data.dropna()

# %%
data_baru.isnull().sum()
# Out:
# Review #    0
# Brand       0
# Variety     0
# Style       0
# Country     0
# Stars       0
# Top Ten     0
# dtype: int64

# %%
data.to_csv('Ramen_Ratings.csv',index=False)
